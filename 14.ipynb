# %%
import numpy as np
from PIL import Image

def average_images(image_list):
    total_array = np.array(Image.open(image_list[0]), 'f')
    count=1

    for image_path in image_list[1:]:
        try:
            image_array = np.array(Image.open(image_path), 'f')
            total_array += image_array
            count=count+1
        except:
            print("Skip ", image_path);

    # Tính trung bình
    average_array = total_array / count

    # Chuyển đổi kết quả trung bình thành hình ảnh
    average_image = Image.fromarray(average_array.astype('uint8'))

    return average_image

# Sử dụng ví dụ:
my_path_1 = 'D:/anh/01.png'
my_path_2 = 'D:/anh/02.png'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)


# Sử dụng ví dụ:
my_path_1 = 'C:/Users/tungi/OneDrive/Documents/src_cv/img/01/1.jpg'
my_path_2 = 'C:/Users/tungi/OneDrive/Documents/src_cv/img/01/2.jpg'
image_list = [my_path_1, my_path_2]
result_image = average_images(image_list)
display(result_image)
# Out:
# Skip  D:/anh/02.png
# <PIL.Image.Image image mode=RGBA size=679x453>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 36
#      34 my_path_2 = 'D:/anh/01/02.png'
#      35 image_list = [my_path_1, my_path_2]
# ---> 36 result_image = average_images(image_list)
#      37 display(result_image)
#
# Cell In[8], line 5, in average_images(image_list)
#       4 def average_images(image_list):
# ----> 5     total_array = np.array(Image.open(image_list[0]), 'f')
#       6     count=1
#       8     for image_path in image_list[1:]:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\PIL\Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\anh\\01\\01.png'
