# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path = 'D:/anh/01.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=679x453>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (679, 453)

# %%
# Thay đổi kích thước
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=50x33>
