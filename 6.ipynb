# %%
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path ='D:/anh/01.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=679x453>

# %%
# chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=679x453>

# %%
# Phân RGB thành 3 tầng màu khác nhau
red_band, green_band, blue_band, alpha_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
display(alpha_band)
# Out:
# <PIL.Image.Image image mode=L size=679x453>
# <PIL.Image.Image image mode=L size=679x453>
# <PIL.Image.Image image mode=L size=679x453>
# <PIL.Image.Image image mode=L size=679x453>

# %%
# Trộn ảnh
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=679x453>
